# %%
import numpy as np
import pandas as pd
from sklearn.utils import resample
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
# !unzip "/content/archive (25).zip"
# Out:
# Archive:  /content/archive (25).zip
#   inflating: diabetes_dataset.csv

# %%
data= pd.read_csv("/content/diabetes_dataset.csv")

# %%
data.head()
# Out:
#    Age  Pregnancies    BMI  Glucose  ...  DietType  Hypertension  MedicationUse  Outcome
# 0   69            5  28.39    130.1  ...         0             0              1        0
# 1   32            1  26.49    116.5  ...         0             0              0        0
# 2   89           13  25.34    101.0  ...         0             0              1        0
# 3   78           13  29.91    146.0  ...         0             0              1        1
# 4   38            8  24.56    103.2  ...         1             0              0        0
#
# [5 rows x 17 columns]

# %%
data.shape
# Out:
# (9538, 17)

# %%
data.describe()
# Out:
#                Age  Pregnancies          BMI  ...  Hypertension  MedicationUse      Outcome
# count  9538.000000  9538.000000  9538.000000  ...   9538.000000    9538.000000  9538.000000
# mean     53.577584     7.986161    27.052364  ...      0.001048       0.405012     0.344097
# std      20.764651     4.933469     5.927955  ...      0.032364       0.490920     0.475098
# min      18.000000     0.000000    15.000000  ...      0.000000       0.000000     0.000000
# 25%      36.000000     4.000000    22.870000  ...      0.000000       0.000000     0.000000
# 50%      53.000000     8.000000    27.050000  ...      0.000000       0.000000     0.000000
# 75%      72.000000    12.000000    31.180000  ...      0.000000       1.000000     1.000000
# max      89.000000    16.000000    49.660000  ...      1.000000       1.000000     1.000000
#
# [8 rows x 17 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9538 entries, 0 to 9537
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 9538 non-null   int64
#  1   Pregnancies         9538 non-null   int64
#  2   BMI                 9538 non-null   float64
#  3   Glucose             9538 non-null   float64
#  4   BloodPressure       9538 non-null   float64
#  5   HbA1c               9538 non-null   float64
#  6   LDL                 9538 non-null   float64
#  7   HDL                 9538 non-null   float64
#  8   Triglycerides       9538 non-null   float64
#  9   WaistCircumference  9538 non-null   float64
#  10  HipCircumference    9538 non-null   float64
#  11  WHR                 9538 non-null   float64
#  12  FamilyHistory       9538 non-null   int64
#  13  DietType            9538 non-null   int64
#  14  Hypertension        9538 non-null   int64
#  15  MedicationUse       9538 non-null   int64
#  16  Outcome             9538 non-null   int64
# dtypes: float64(10), int64(7)
# memory usage: 1.2 MB

# %%
data['Outcome'].value_counts()
# Out:
# Outcome
# 0    6256
# 1    3282
# Name: count, dtype: int64

# %%
minority_data= data[data['Outcome']==1]
majority_data= data[data['Outcome']==0]

# %%
minority_data.shape
# Out:
# (3282, 17)

# %%
majority_data.shape
# Out:
# (6256, 17)

# %%
resample?

# %%
minority_data_resampled= resample(minority_data,
                                  replace=True,
                                  n_samples=len(majority_data),
                                  random_state=42)

# %%
minority_data.describe()
# Out:
#                Age  Pregnancies          BMI  ...  Hypertension  MedicationUse  Outcome
# count  3282.000000  3282.000000  3282.000000  ...   3282.000000    3282.000000   3282.0
# mean     55.539915     7.862279    27.930070  ...      0.002438       0.448812      1.0
# std      21.099171     4.952679     6.159695  ...      0.049319       0.497449      0.0
# min      18.000000     0.000000    15.000000  ...      0.000000       0.000000      1.0
# 25%      37.000000     3.000000    23.802500  ...      0.000000       0.000000      1.0
# 50%      56.500000     8.000000    27.890000  ...      0.000000       0.000000      1.0
# 75%      74.000000    12.000000    32.045000  ...      0.000000       1.000000      1.0
# max      89.000000    16.000000    49.660000  ...      1.000000       1.000000      1.0
#
# [8 rows x 17 columns]

# %%
minority_data_resampled.head()
# Out:
#       Age  Pregnancies    BMI  Glucose  ...  DietType  Hypertension  MedicationUse  Outcome
# 9234   73           12  21.38    108.3  ...         0             0              1        1
# 2509   39            5  31.38     90.3  ...         1             0              0        1
# 3817   76            0  15.18     99.8  ...         1             0              1        1
# 3370   58            9  22.75     71.5  ...         0             0              0        1
# 3253   58           13  20.79     92.0  ...         1             0              0        1
#
# [5 rows x 17 columns]

# %%
new_data= pd.concat([majority_data, minority_data_resampled])

# %%
new_data.head()
# Out:
#    Age  Pregnancies    BMI  Glucose  ...  DietType  Hypertension  MedicationUse  Outcome
# 0   69            5  28.39    130.1  ...         0             0              1        0
# 1   32            1  26.49    116.5  ...         0             0              0        0
# 2   89           13  25.34    101.0  ...         0             0              1        0
# 4   38            8  24.56    103.2  ...         1             0              0        0
# 6   20           16  15.76     61.6  ...         1             0              0        0
#
# [5 rows x 17 columns]

# %%
new_data.groupby('Outcome')

# %%
new_data.reset_index(drop=True, inplace=True)

# %%
# Out:
#    Age  Pregnancies    BMI  Glucose  ...  DietType  Hypertension  MedicationUse  Outcome
# 0   69            5  28.39    130.1  ...         0             0              1        0
# 1   32            1  26.49    116.5  ...         0             0              0        0
# 2   89           13  25.34    101.0  ...         0             0              1        0
# 3   38            8  24.56    103.2  ...         1             0              0        0
# 4   20           16  15.76     61.6  ...         1             0              0        0
#
# [5 rows x 17 columns]

# %%
from sklearn.utils import shuffle

# %%
new_data= shuffle(new_data, random_state=2)

# %%
new_data.reset_index(drop=True, inplace=True)

# %%
new_data.head()
# Out:
#    Age  Pregnancies    BMI  Glucose  ...  DietType  Hypertension  MedicationUse  Outcome
# 0   82           11  34.12    149.3  ...         0             0              1        1
# 1   37           12  26.10     79.3  ...         0             0              0        1
# 2   63           13  27.85    113.0  ...         1             0              1        1
# 3   67           11  22.21     83.6  ...         0             0              1        1
# 4   70            3  30.74    142.3  ...         1             0              1        1
#
# [5 rows x 17 columns]

# %%
new_data.shape
# Out:
# (12512, 17)

# %%
new_data.describe()
# Out:
#                 Age   Pregnancies           BMI  ...  Hypertension  MedicationUse      Outcome
# count  12512.000000  12512.000000  12512.000000  ...  12512.000000   12512.000000  12512.00000
# mean      53.990010      7.941496     27.260981  ...      0.001838       0.415121      0.50000
# std       20.892334      4.936858      5.968589  ...      0.042837       0.492763      0.50002
# min       18.000000      0.000000     15.000000  ...      0.000000       0.000000      0.00000
# 25%       36.000000      4.000000     23.090000  ...      0.000000       0.000000      0.00000
# 50%       54.000000      8.000000     27.235000  ...      0.000000       0.000000      0.50000
# 75%       73.000000     12.000000     31.450000  ...      0.000000       1.000000      1.00000
# max       89.000000     16.000000     49.660000  ...      1.000000       1.000000      1.00000
#
# [8 rows x 17 columns]

# %%
data.describe()
# Out:
#                Age  Pregnancies          BMI  ...  Hypertension  MedicationUse      Outcome
# count  9538.000000  9538.000000  9538.000000  ...   9538.000000    9538.000000  9538.000000
# mean     53.577584     7.986161    27.052364  ...      0.001048       0.405012     0.344097
# std      20.764651     4.933469     5.927955  ...      0.032364       0.490920     0.475098
# min      18.000000     0.000000    15.000000  ...      0.000000       0.000000     0.000000
# 25%      36.000000     4.000000    22.870000  ...      0.000000       0.000000     0.000000
# 50%      53.000000     8.000000    27.050000  ...      0.000000       0.000000     0.000000
# 75%      72.000000    12.000000    31.180000  ...      0.000000       1.000000     1.000000
# max      89.000000    16.000000    49.660000  ...      1.000000       1.000000     1.000000
#
# [8 rows x 17 columns]

# %%
X= new_data.drop(['Outcome'], axis=1)
Y= new_data['Outcome']

# %%
X_train, X_test, Y_train, Y_test= train_test_split(X, Y, test_size=0.25, random_state=2)

# %%
Y_train.shape
# Out:
# (9384,)

# %%
model= RandomForestClassifier(n_estimators=100, random_state=42)

# %%
from sklearn.metrics import accuracy_score

# %%
class model_trainer_and_evaluator():

  def train_model(model, X_train, Y_train):
    model.fit(X_train, Y_train)
    return model

  def evaluate_model(metric, model, X_test, Y_test):
    y_pred= model.predict(X_test)
    acc_score= metric(Y_test, y_pred)
    return acc_score

# %%
model1= model_trainer_and_evaluator.train_model(model, X_train, Y_train)

# %%
acc_score= model_trainer_and_evaluator.evaluate_model(accuracy_score, model1, X_test, Y_test)
print(acc_score)
# Out:
# 1.0

# %%
import pickle

# %%
pickle.dump(model1, open("diabetes_model", "wb"))

# %%
pickle.dump(model1, open("diabetes_model.pkl", "wb"))
